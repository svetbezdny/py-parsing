# %%
import pandas as pd
import numpy as np

from rosstat import load_info

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
info = load_info()
# Out:
# Актуальность данных: 21.03.2024

# %%
info
# Out:
# {'actual_date': '21.03.2024',
#  'Основные характеристики субъектов российской федерации': 'https://rosstat.gov.ru/storage/2024/03-21/RzFCM6ER/Sbornik_Reg_Rus_Pokaz_2023/RR_pokaz_01_2023.xlsx',
#  'Население': 'https://rosstat.gov.ru/storage/2024/03-21/RzFCM6ER/Sbornik_Reg_Rus_Pokaz_2023/RR_pokaz_02_2023.xlsx',
#  'Труд': 'https://rosstat.gov.ru/storage/2024/03-21/RzFCM6ER/Sbornik_Reg_Rus_Pokaz_2023/RR_pokaz_03_2023.xlsx',
#  'Уровень жизни населения': 'https://rosstat.gov.ru/storage/2024/03-21/RzFCM6ER/Sbornik_Reg_Rus_Pokaz_2023/RR_pokaz_04_2023.xlsx',
#  'Образование': 'https://rosstat.gov.ru/storage/2024/03-21/RzFCM6ER/Sbornik_Reg_Rus_Pokaz_2023/RR_pokaz_05_2023.xlsx',
#  'Здравоохранение': 'https://rosstat.gov.ru/storage/2024/03-21/RzFCM6ER/Sbornik_Reg_Rus_Pokaz_2023/RR_pokaz_06_2023.xlsx',
#  'Культура, отдых и туризм': 'https://rosstat.gov.ru/storage/2024/03-21/RzFCM6ER/Sbornik_Reg_Rus_Pokaz_2023/RR_pokaz_07_2023.xlsx',
# ...

# %%
content = pd.ExcelFile(info['Население']).sheet_names

# %%
t = pd.read_excel(info["Население"], sheet_name="Содержание")
t
# Out:
#    2. НАСЕЛЕНИЕ  \
# 0          2.1.
# 1          2.2.
# 2          2.3.
# 3          2.4.
# 4          2.5.
# 5          2.6.
# 6          2.7.
# 7          2.8.
# 8          2.9.
# 9         2.10.
# 10        2.11.
# 11        2.12.
# 12        2.13.
# 13       2.14.
# 14        2.15.
# 15       2.16.
# 16        2.17.
# 17        2.18.
# 18        2.19.
# 19        2.20.
# 20        2.21.
# 21        2.22.
# 22        2.23.
# 23        2.24.
#
#                                                                        Unnamed: 1
# 0                                                          Численность населения
# 1                                           Среднегодовая численность населения
# 2   Удельный вес городского и сельского населения в общей численности населения
# 3                                                   Соотношение мужчин и женщин
# 4                                                   Возрастной состав населения
# ...

# %%
for sheet in content[1:]:
    df = pd.read_excel(info["Население"], sheet_name=sheet)
    display(df[:3])
    print()
# Out:
#   2.1. ЧИСЛЕННОСТЬ НАСЕЛЕНИЯ  \n(оценка на конец года; тысяч человек)  \
# 0                                                                 NaN
# 1                                                Российская Федерация
# 2                                       Центральный федеральный округ
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0       2005       2010       2015       2020       2021       2022
# 1  143 236,6  142 865,4  147 182,3  147 455,7  146 980,1  146 447,4
# 2   38 109,0   38 445,7   39 650,3   40 341,0   40 298,1   40 240,3
#   2.2. СРЕДНЕГОДОВАЯ ЧИСЛЕННОСТЬ НАСЕЛЕНИЯ\n (оценка; тысяч человек)  \
# 0                                                                NaN
# 1                                               Российская Федерация
# 2                                      Центральный федеральный округ
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# ...
